# %% [markdown]
# # Competição de DataScience Titanic no Kaggle

# %% [markdown]
# Escolhi esse projeto pois ele se mostra uma boa opção para aprender conceitos básicos da área de dados, como:
# 1. Análise Exploratória de dados
# 2. Visualização de dados
# 3. Conceitos de Estatística
# 4. Machine Learning

# %% [markdown]
# # Explicação do projeto

# %% [markdown]
# Ele é uma competição do site [Kaggle](kaggle.com) em que o objetivo é prever a sobrevivência ou não de passageiros após o naufrágio do navio Titanic.

# %% [markdown]
# Os participantes da competição recebem duas bases de dados, uma para treinar o modelo, com todos os dados das pessoas, inclusive se elas sobreviveram ou não e outra para testar o modelo, que contém todos os dados, exceto se sobreviveram ou não.
#
# O objetivo é ter a maior acurácia possível ao aplicar o modelo na base de dados de teste.

# %% [markdown]
# # Execução do projeto

# %% [markdown]
# ## Parte 0: Importando as bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Parte 1: Análise exploratória dos dados
# O objetivo dessa fase é simples: descobrir do que consiste a base de dados. Quais são as colunas da tabela, encontrar dados inconsistentes e descobrir estatísitcas gerais sobre os dados.
# Apesar de ser simples, entender os dados é fundamental para criar um modelo preciso de Machine Learning.

# %%
dados = pd.read_csv("./data/train.csv")

# %%
dados.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
